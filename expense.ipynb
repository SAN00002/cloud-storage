# %% [markdown]
# <a href="https://colab.research.google.com/github/SAN00002/cloud-storage/blob/main/expense.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

df=pd.read_excel("/expenses.xlsx")
df.head()
df.isnull().sum()
df.dropna(inplace=True)
df.dtypes
df['Date'] = pd.to_datetime(df['Date'])
df.drop_duplicates(inplace=True)
df['Category'] = df['Category'].str.strip().str.title()
df['Week'] = df['Date'].dt.isocalendar().week
df['Month'] = df['Date'].dt.month
df = df.sort_values(by='Date')
df.to_csv("cleaned_expenses.csv", index=False)
print(df.describe(include='all')
)
print(df['Category'].value_counts())
df['Category'].value_counts().plot(kind='barh', title='Spending by Category')
weekly = df.groupby('Week')['Amount (₹)'].sum()
weekly.plot(kind='line', marker='o', title='Weekly Expense Trend')

import matplotlib.pyplot as plt
plt.xlabel('Week Number')
plt.ylabel('Total Spending (₹)')
plt.grid(True)
plt.tight_layout()
plt.show()
df['Category'].value_counts().plot(kind='bar', title='Spending by Category')

plt.xlabel("Category")
plt.ylabel("Number of Entries")
plt.tight_layout()
plt.show()

df[df['Recurring?'] == 'Yes']['Category'].value_counts()
df[df['Recurring?'] == 'Yes']['Category'].value_counts().plot(kind='bar')
# Out:
#                                  Date  Amount (₹) Category Payment Method  \
# count                              22   22.000000       22             22
# unique                            NaN         NaN        8              1
# top                               NaN         NaN     Food            UPI
# freq                              NaN         NaN        9             22
# mean    2025-05-02 06:32:43.636363520  126.545455      NaN            NaN
# min               2025-04-05 00:00:00   10.000000      NaN            NaN
# 25%               2025-04-24 06:00:00   65.000000      NaN            NaN
# 50%               2025-04-29 12:00:00  146.500000      NaN            NaN
# 75%               2025-05-12 18:00:00  190.750000      NaN            NaN
# max               2025-05-25 00:00:00  236.000000      NaN            NaN
# std                               NaN   71.062499      NaN            NaN
#
#        Description Need or Want? Recurring?       Week      Month
# ...
